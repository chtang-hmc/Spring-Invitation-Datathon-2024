# %%
from linear_model import *
from sklearn.datasets import load_diabetes

# %%
df = load_diabetes(as_frame=True).frame

# %%
X = df.drop(columns='target')
y = df['target']
model = test_linear_model(X, y)
# Out:
# The p-value for the F-test is: 3.828649038185173e-62.
# The model is statistically significant.
# The null hypothesis for the Jarque-Bera test is normality.
# {'Jarque-Bera': 1.4037553754121688, 'Chi^2 two-tail prob.': 0.49565374653196514, 'Skew': 0.016533573714358967, 'Kurtosis': 2.7259040768352714}
# The residuals are normally distributed.
# The null hypothesis for the Breusch-Pagan test is homoscedasticity.
# {'Lagrange multiplier statistic': 26.145362742107928, 'p-value': 0.00354952241928149, 'f-value': 2.7097572883046324, 'f p-value': 0.0030981318142945763}
# The residuals are heteroscedastic.
# The null hypothesis for the Durbin-Watson test is no autocorrelation.
# {'Durbin-Watson': 2.0285432192544266, 'p-value': 0.04250483696483709}
# The residuals are autocorrelated.
# The correlation matrix is:
#    Variable        VIF
# 0     const   1.000000
# 1       age   1.217307
# 2       sex   1.278071
# 3       bmi   1.509437
# 4        bp   1.459428
# 5        s1  59.202510
# 6        s2  39.193370
# 7        s3  15.402156
# 8        s4   8.890986
# 9        s5  10.075967
# 10       s6   1.484623
# There is multicollinearity in the model.

# %%
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                 target   R-squared:                       0.518
# Model:                            OLS   Adj. R-squared:                  0.507
# Method:                 Least Squares   F-statistic:                     46.27
# Date:                Tue, 02 Apr 2024   Prob (F-statistic):           3.83e-62
# Time:                        22:02:47   Log-Likelihood:                -2386.0
# No. Observations:                 442   AIC:                             4794.
# Df Residuals:                     431   BIC:                             4839.
# Df Model:                          10
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const        152.1335      2.576     59.061      0.000     147.071     157.196
# age          -10.0099     59.749     -0.168      0.867    -127.446     107.426
# sex         -239.8156     61.222     -3.917      0.000    -360.147    -119.484
# bmi          519.8459     66.533      7.813      0.000     389.076     650.616
# bp           324.3846     65.422      4.958      0.000     195.799     452.970
# s1          -792.1756    416.680     -1.901      0.058   -1611.153      26.802
# s2           476.7390    339.030      1.406      0.160    -189.620    1143.098
# s3           101.0433    212.531      0.475      0.635    -316.684     518.770
# s4           177.0632    161.476      1.097      0.273    -140.315     494.441
# s5           751.2737    171.900      4.370      0.000     413.407    1089.140
# s6            67.6267     65.984      1.025      0.306     -62.064     197.318
# ==============================================================================
# Omnibus:                        1.506   Durbin-Watson:                   2.029
# Prob(Omnibus):                  0.471   Jarque-Bera (JB):                1.404
# Skew:                           0.017   Prob(JB):                        0.496
# Kurtosis:                       2.726   Cond. No.                         227.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """
