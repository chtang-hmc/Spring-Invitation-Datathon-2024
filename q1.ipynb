# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
# import tensorflow as tf
# import keras

# %%
oil = pd.read_csv("/Users/ishitajain/stocks-web-app/Spring-Invitation-Datathon-2024/clean_data/cleaned_merged_emissions_consumption.csv")
temp = pd.read_csv("/Users/ishitajain/stocks-web-app/Spring-Invitation-Datathon-2024/clean_data/temp.csv")
# Out:
# /var/folders/wk/48ywwld12k3b18wmjf4yr1080000gn/T/ipykernel_56599/713681304.py:1: DtypeWarning: Columns (3) have mixed types. Specify dtype option on import or set low_memory=False.
#   oil = pd.read_csv("/Users/ishitajain/stocks-web-app/Spring-Invitation-Datathon-2024/clean_data/cleaned_merged_emissions_consumption.csv")

# %%
oil['Energy Type'].value_counts()
# Out:
# Total                                 18589
# Distillate Fuel Oil                    6721
# Coal                                   6698
# Natural Gas                            6406
# Residual Fuel Oil                      5499
# Kerosene                               4277
# Motor Gasoline                         4277
# Petroleum Coke                         3893
# Lubricants                             3055
# Hydrocarbon Gas Liquids (HGL)          3055
# Biomass                                2959
# Electricity                            2444
# Wood Energy                            2444
# Propane                                2444
# Geothermal Energy                      2287
# Aviation Gasoline                      1833
# Jet Fuel                               1833
# Total Renewable Energy                 1833
# Solar Energy                           1736
# Hydroelectric Power                    1633
# Waste Energy                           1545
# ...

# %%
oil
# Out:
#          EIA_ID  YYYYMM       Date     Value  Column_Order  \
# 0       DFRCPUS  197301   1/1/1973  1706.943             1
# 1       DFRCPUS  197302   2/1/1973  1614.436             1
# 2       DFRCPUS  197303   3/1/1973  1140.521             1
# 3       DFRCPUS  197304   4/1/1973   824.604             1
# 4       DFRCPUS  197305   5/1/1973   676.745             1
# ...         ...     ...        ...       ...           ...
# 100066  BMTCEUS  202307   7/1/2023     26.54            11
# 100067  BMTCEUS  202308   8/1/2023    27.032            11
# 100068  BMTCEUS  202309   9/1/2023    25.438            11
# 100069  BMTCEUS  202310  10/1/2023    26.215            11
# 100070  BMTCEUS  202311  11/1/2023    26.109            11
#
#                                               Description  \
# 0       Distillate Fuel Oil Consumed by the Residentia...
# 1       Distillate Fuel Oil Consumed by the Residentia...
# 2       Distillate Fuel Oil Consumed by the Residentia...
# ...

# %%
temp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1997 entries, 0 to 1996
# Data columns (total 3 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  1997 non-null   int64
#  1   anomaly     1997 non-null   float64
#  2   date        1997 non-null   object
# dtypes: float64(1), int64(1), object(1)
# memory usage: 46.9+ KB

# %%
temp[1]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/miniforge3/envs/env_python38/lib/python3.8/site-packages/pandas/core/indexes/base.py:3802, in Index.get_loc(self, key, method, tolerance)
#    3801 try:
# -> 3802     return self._engine.get_loc(casted_key)
#    3803 except KeyError as err:
#
# File ~/miniforge3/envs/env_python38/lib/python3.8/site-packages/pandas/_libs/index.pyx:138, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~/miniforge3/envs/env_python38/lib/python3.8/site-packages/pandas/_libs/index.pyx:165, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:5745, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:5753, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 1
#
# The above exception was the direct cause of the following exception:
#
# ...

# %%
temp
# Out:
#       Unnamed: 0  anomaly        date
# 0              0    1.142  1950-01-01
# 1              1   -0.015  1950-02-01
# 2              2   -0.180  1950-03-01
# 3              3   -0.973  1950-04-01
# 4              4   -0.467  1950-05-01
# ...          ...      ...         ...
# 1992        1992   -0.019  1949-08-01
# 1993        1993   -0.278  1949-09-01
# 1994        1994    0.212  1949-10-01
# 1995        1995    2.429  1949-11-01
# 1996        1996    0.055  1949-12-01
#
# [1997 rows x 3 columns]

# %%
temp["anom_squared"] = temp["anomaly"] **2

# %%
temp["date"] = pd.to_datetime(temp["date"])

# %%
sns.scatterplot(temp,x="date",y="anom_squared")
# Out:
# <Axes: xlabel='date', ylabel='anom_squared'>

# %%
sns.
# Out:
#          EIA_ID  YYYYMM       Date     Value  Column_Order  \
# 0       DFRCPUS  197301   1/1/1973  1706.943             1
# 1       DFRCPUS  197302   2/1/1973  1614.436             1
# 2       DFRCPUS  197303   3/1/1973  1140.521             1
# 3       DFRCPUS  197304   4/1/1973   824.604             1
# 4       DFRCPUS  197305   5/1/1973   676.745             1
# ...         ...     ...        ...       ...           ...
# 100066  BMTCEUS  202307   7/1/2023     26.54            11
# 100067  BMTCEUS  202308   8/1/2023    27.032            11
# 100068  BMTCEUS  202309   9/1/2023    25.438            11
# 100069  BMTCEUS  202310  10/1/2023    26.215            11
# 100070  BMTCEUS  202311  11/1/2023    26.109            11
#
#                                               Description  \
# 0       Distillate Fuel Oil Consumed by the Residentia...
# 1       Distillate Fuel Oil Consumed by the Residentia...
# 2       Distillate Fuel Oil Consumed by the Residentia...
# ...
